# %% [markdown]
# <a href="https://colab.research.google.com/github/smartivar007/testrepo/blob/childbranch/DatascienceEcosystem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data science tools and ecosystem

# %% [markdown]
# In this notebook , Data Science Tools and Ecosystem are summarised

# %% [markdown]
# List of languages for data science

# %%
list1=['Python','R','SQL','Java','Scala','JavaScript']
list1.sort()
print(list1)
# Out:
# ['Java', 'JavaScript', 'Python', 'R', 'SQL', 'Scala']

# %% [markdown]
# Data Science Tools

# %%
get_ipython().system('pip install tabulate')
from tabulate import tabulate
data_dict={'Data Tools':['ProjectJupyter','Tableau','TensorFlow','Apache Spark','Scikit-learn','Apache Hadoop']}
print(tabulate(data_dict,headers='keys',tablefmt='grid'))
# Out:
# ...
# +----------------+
# | Data Tools     |
# +================+
# | ProjectJupyter |
# +----------------+
# | Tableau        |
# +----------------+
# | TensorFlow     |
# +----------------+
# | Apache Spark   |
# +----------------+
# | Scikit-learn   |
# +----------------+
# | Apache Hadoop  |
# +----------------+

# %% [markdown]
# <h3>Below are a few examples of evaluating arithmetic expressions in Python

# %%
#This is a simple arithmetic expression to multiply and add numbers
(3*4)+5
# Out:
# 17

# %%
#This will convert 200 minutes into hours bydeviding by 60
200/60
# Out:
# 3.3333333333333335

# %% [markdown]
# **objectives** of this notebook
# * Languages of Data Science
# * Common Libraries used bt Data Scientists.
# * Tools for Data Science
# * Examples of arithmetic expressions

# %% [markdown]
# Author Ivar Joseph D'Lima
